# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.datasets import load_breast_cancer
ds = load_breast_cancer()
X = ds['data']
y = ds['target']

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost importu XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import numpy as np

# %%
tuned_parameters = [
                    [{'max_depth' : [10,100,1000,10000], 'min_samples_split' : [2,10,100], 'min_samples_leaf': [1,5,10], 'max_features' : ["sqrt","log2"]}],
                    [{'activation' : ['logistic','tanh','relu'],'hidden_layer_sizes' : [(3,),(6,)], 'max_iter' : [100,500],'alpha' : [0.0001,0.0005]}],
					          [{'kernel': ['rbf', 'linear','poly'], 'gamma': [1e-3, 1e-4],'C': [1, 10, 100, 1000]}],
                    [{'priors': [np.array([0.1,0.9])]}], 
                    [{'penalty': ['l1','l2'], 'tol' : [1e-5,1e-6], 'max_iter' : [10,100,1000], 'fit_intercept' : [True, False]}],
                    [{'n_neighbors' : [3,5,10],'weights': ['uniform','distance'], 'algorithm' : ['ball_tree', 'kd_tree', 'brute'],'p' : [1,2,3]}],
                    [{'n_estimators':[10,25,50,100],'max_samples':[0.5,1.0],'max_features':[0.5,1.0],'random_state':[None]}],
                    [{'n_estimators':[10,25,50,100],'max_features':[0.5,1.0],'criterion' : ['gini','entropy'],'max_depth': [None,100,200]}],
                    [{'n_estimators' : [50,100,150,200],'random_state' : [None], 'learning_rate' : [1.,0.8,0.5],'algorithm' : ['SAMME','SAMME.R']}],
                    [{'loss': ['deviance', 'exponential'],'learning_rate':[0.1,0.5],'n_estimators' : [100,250,400,500],'max_features' : ['log2','sqrt'],'max_depth' : [3,10,50] }],
                    [{'learning_rate' : [0.1,0.05,0.2],'n_estimators' : [100,250,400,500],'booster': ['gbtree', 'gblinear' ,'dart'], 'min_child_weight' : [1], 'max_delta_step' : [0]}]
                    ]

scores = ['precision', 'recall']

# %%
classifier = [DecisionTreeClassifier(),MLPClassifier(),SVC(),GaussianNB(),LogisticRegression(),KNeighborsClassifier(),BaggingClassifier(),RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),XGBClassifier()]
cls_name = ["Decision Tree","Neural Networks","Support Vector Machine","Naive Bayes","Logistic Regression","K-Nearest Neighbors","Bagging Method","Random Forest Model","AdaBoost Model","Gradient Boosting","XGB Model"]

# %%
for i in range(0,len(classifier)):
  print("\n-------------Showing below the results obtained using %s-----------------\n" %cls_name[i])
  for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(classifier[i], tuned_parameters[i], cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Average Accuracy Score: \n")
    print(clf.score(X_test, y_test))
    print()
    print("#############################################################################################################################")
# Out:
# -------------Showing below the results obtained using Decision Tree-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Grid scores on development set:
#
# 0.905 (+/-0.038) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.899 (+/-0.043) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.914 (+/-0.052) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.911 (+/-0.068) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.894 (+/-0.060) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.875 (+/-0.065) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.914 (+/-0.039) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.902 (+/-0.069) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.901 (+/-0.040) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.912 (+/-0.047) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.882 (+/-0.065) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.881 (+/-0.079) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.914 (+/-0.041) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.931 (+/-0.044) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.896 (+/-0.033) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.905 (+/-0.075) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.903 (+/-0.057) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.873 (+/-0.086) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.926 (+/-0.045) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.906 (+/-0.031) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.896 (+/-0.029) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.918 (+/-0.053) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.912 (+/-0.053) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.034) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.906 (+/-0.039) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.898 (+/-0.059) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.882 (+/-0.058) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.914 (+/-0.098) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.922 (+/-0.057) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.894 (+/-0.056) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.911 (+/-0.025) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.932 (+/-0.053) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.906 (+/-0.087) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.922 (+/-0.040) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.889 (+/-0.058) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.875 (+/-0.087) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.911 (+/-0.076) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.036) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.904 (+/-0.051) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.928 (+/-0.041) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.914 (+/-0.048) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.907 (+/-0.033) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.923 (+/-0.036) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.901 (+/-0.050) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.887 (+/-0.030) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.894 (+/-0.047) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.056) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.871 (+/-0.052) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.908 (+/-0.073) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.932 (+/-0.031) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.895 (+/-0.039) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.897 (+/-0.081) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.900 (+/-0.044) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.888 (+/-0.052) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.912 (+/-0.064) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.915 (+/-0.043) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.906 (+/-0.038) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.913 (+/-0.039) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.920 (+/-0.037) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.915 (+/-0.027) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.910 (+/-0.041) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.918 (+/-0.057) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.899 (+/-0.080) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.926 (+/-0.027) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.903 (+/-0.048) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.910 (+/-0.037) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.927 (+/-0.079) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.913 (+/-0.067) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.910 (+/-0.058) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.920 (+/-0.055) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.922 (+/-0.065) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.897 (+/-0.057) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        47
#            1       0.97      0.93      0.95        67
#
#     accuracy                           0.94       114
#    macro avg       0.93      0.94      0.94       114
# weighted avg       0.94      0.94      0.94       114
#
# Average Accuracy Score:
#
# 0.934375
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Grid scores on development set:
#
# 0.905 (+/-0.065) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.902 (+/-0.051) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.879 (+/-0.036) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.917 (+/-0.073) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.012) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.034) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.894 (+/-0.051) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.054) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.892 (+/-0.058) for {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.929 (+/-0.047) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.067) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.912 (+/-0.069) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.930 (+/-0.057) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.929 (+/-0.030) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.913 (+/-0.048) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.910 (+/-0.096) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.908 (+/-0.054) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.886 (+/-0.103) for {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.910 (+/-0.052) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.922 (+/-0.078) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.910 (+/-0.055) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.915 (+/-0.059) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.904 (+/-0.038) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.886 (+/-0.059) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.900 (+/-0.064) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.912 (+/-0.066) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.886 (+/-0.061) for {'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.907 (+/-0.056) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.926 (+/-0.041) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.914 (+/-0.052) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.914 (+/-0.023) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.910 (+/-0.006) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.882 (+/-0.058) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.906 (+/-0.046) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.891 (+/-0.074) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.868 (+/-0.021) for {'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.927 (+/-0.054) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.899 (+/-0.009) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.891 (+/-0.050) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.896 (+/-0.086) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.913 (+/-0.038) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.908 (+/-0.059) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.893 (+/-0.047) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.884 (+/-0.032) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.881 (+/-0.067) for {'max_depth': 1000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.908 (+/-0.065) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.895 (+/-0.039) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.871 (+/-0.047) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.908 (+/-0.034) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.922 (+/-0.075) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.905 (+/-0.083) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.903 (+/-0.072) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.895 (+/-0.058) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.885 (+/-0.038) for {'max_depth': 1000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.925 (+/-0.046) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.914 (+/-0.056) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.873 (+/-0.020) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.913 (+/-0.034) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.907 (+/-0.048) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.881 (+/-0.073) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.924 (+/-0.047) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.904 (+/-0.034) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.886 (+/-0.052) for {'max_depth': 10000, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 100}
# 0.909 (+/-0.042) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.907 (+/-0.048) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.895 (+/-0.025) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 100}
# 0.904 (+/-0.029) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.898 (+/-0.049) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.873 (+/-0.048) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 100}
# 0.920 (+/-0.055) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.905 (+/-0.057) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.886 (+/-0.060) for {'max_depth': 10000, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 100}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        47
#            1       0.98      0.93      0.95        67
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.95       114
# weighted avg       0.95      0.95      0.95       114
#
# Average Accuracy Score:
#
# 0.9520482692918386
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using Neural Networks-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
#
# Grid scores on development set:
#
# 0.933 (+/-0.070) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.980 (+/-0.024) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.942 (+/-0.039) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.980 (+/-0.027) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.904 (+/-0.030) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.980 (+/-0.022) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.938 (+/-0.032) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.982 (+/-0.028) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.948 (+/-0.049) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.981 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.954 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.978 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.963 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.971 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.950 (+/-0.045) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.985 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.783 (+/-0.607) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.962 (+/-0.028) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.936 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.979 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.903 (+/-0.026) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.968 (+/-0.022) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.941 (+/-0.033) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.974 (+/-0.026) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        47
#            1       0.97      0.99      0.98        67
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Average Accuracy Score:
#
# 0.9744245524296675
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
#
# Grid scores on development set:
#
# 0.902 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.965 (+/-0.024) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.932 (+/-0.063) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.971 (+/-0.029) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.746 (+/-0.406) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.968 (+/-0.044) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.917 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.975 (+/-0.036) for {'activation': 'logistic', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.941 (+/-0.070) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.972 (+/-0.046) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.964 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.977 (+/-0.040) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.910 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.964 (+/-0.034) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.948 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.970 (+/-0.031) for {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.837 (+/-0.342) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.973 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.958 (+/-0.023) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.974 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# 0.887 (+/-0.154) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 100}
# 0.974 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (3,), 'max_iter': 500}
# 0.869 (+/-0.374) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 100}
# 0.964 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0005, 'hidden_layer_sizes': (6,), 'max_iter': 500}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        47
#            1       0.98      0.97      0.98        67
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Average Accuracy Score:
#
# 0.9744363289933312
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using Support Vector Machine-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.961 (+/-0.026) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.967 (+/-0.036) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.319 (+/-0.000) for {'C': 1, 'gamma': 0.001, 'kernel': 'poly'}
# 0.853 (+/-0.013) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.967 (+/-0.036) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.319 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.977 (+/-0.035) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.960 (+/-0.062) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.520 (+/-0.493) for {'C': 10, 'gamma': 0.001, 'kernel': 'poly'}
# 0.961 (+/-0.026) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.960 (+/-0.062) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.319 (+/-0.000) for {'C': 10, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.982 (+/-0.034) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.950 (+/-0.048) for {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
# 0.829 (+/-0.011) for {'C': 100, 'gamma': 0.001, 'kernel': 'poly'}
# 0.977 (+/-0.035) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.950 (+/-0.048) for {'C': 100, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.319 (+/-0.000) for {'C': 100, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.975 (+/-0.045) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.942 (+/-0.033) for {'C': 1000, 'gamma': 0.001, 'kernel': 'linear'}
# 0.862 (+/-0.015) for {'C': 1000, 'gamma': 0.001, 'kernel': 'poly'}
# 0.982 (+/-0.028) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.942 (+/-0.033) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.319 (+/-0.000) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'poly'}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        47
#            1       0.97      0.97      0.97        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
#
# Average Accuracy Score:
#
# 0.9637980311209908
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.924 (+/-0.054) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.967 (+/-0.043) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 0.001, 'kernel': 'poly'}
# 0.633 (+/-0.045) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.967 (+/-0.043) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.962 (+/-0.048) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.960 (+/-0.068) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.506 (+/-0.015) for {'C': 10, 'gamma': 0.001, 'kernel': 'poly'}
# 0.924 (+/-0.054) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.960 (+/-0.068) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.975 (+/-0.049) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.953 (+/-0.053) for {'C': 100, 'gamma': 0.001, 'kernel': 'linear'}
# 0.542 (+/-0.045) for {'C': 100, 'gamma': 0.001, 'kernel': 'poly'}
# 0.962 (+/-0.048) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.953 (+/-0.053) for {'C': 100, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 0.0001, 'kernel': 'poly'}
# 0.973 (+/-0.053) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.947 (+/-0.039) for {'C': 1000, 'gamma': 0.001, 'kernel': 'linear'}
# 0.664 (+/-0.052) for {'C': 1000, 'gamma': 0.001, 'kernel': 'poly'}
# 0.975 (+/-0.036) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.947 (+/-0.039) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'poly'}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        47
#            1       0.97      0.97      0.97        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
#
# Average Accuracy Score:
#
# 0.9637980311209908
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using Naive Bayes-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'priors': array([0.1, 0.9])}
#
# Grid scores on development set:
#
# 0.947 (+/-0.037) for {'priors': array([0.1, 0.9])}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88        47
#            1       0.92      0.91      0.92        67
#
#     accuracy                           0.90       114
#    macro avg       0.90      0.90      0.90       114
# weighted avg       0.90      0.90      0.90       114
#
# Average Accuracy Score:
#
# 0.8996212121212122
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'priors': array([0.1, 0.9])}
#
# Grid scores on development set:
#
# 0.933 (+/-0.048) for {'priors': array([0.1, 0.9])}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88        47
#            1       0.92      0.91      0.92        67
#
#     accuracy                           0.90       114
#    macro avg       0.90      0.90      0.90       114
# weighted avg       0.90      0.90      0.90       114
#
# Average Accuracy Score:
#
# 0.9020323912353128
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using Logistic Regression-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
#
# Grid scores on development set:
#
# 0.982 (+/-0.037) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
# 0.982 (+/-0.037) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-06}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-05}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-06}
# 0.980 (+/-0.033) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.033) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-06}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-06}
# 0.980 (+/-0.033) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.033) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-06}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 0.981 (+/-0.034) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-06}
# 0.982 (+/-0.037) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
# 0.982 (+/-0.037) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-06}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-05}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-06}
# 0.980 (+/-0.033) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.033) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-06}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-06}
# 0.980 (+/-0.033) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.033) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-06}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 0.982 (+/-0.028) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-06}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        47
#            1       0.96      0.97      0.96        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Average Accuracy Score:
#
# 0.9562020460358056
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
#
# Grid scores on development set:
#
# 0.980 (+/-0.041) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.055) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-06}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-05}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-06}
# 0.978 (+/-0.038) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05}
# 0.978 (+/-0.038) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-06}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-06}
# 0.978 (+/-0.038) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 0.978 (+/-0.038) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-06}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 0.977 (+/-0.048) for {'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-06}
# 0.980 (+/-0.041) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-05}
# 0.980 (+/-0.041) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l1', 'tol': 1e-06}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-05}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 10, 'penalty': 'l2', 'tol': 1e-06}
# 0.978 (+/-0.038) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05}
# 0.978 (+/-0.038) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-06}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-06}
# 0.978 (+/-0.038) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 0.978 (+/-0.038) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-06}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 0.980 (+/-0.037) for {'fit_intercept': False, 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-06}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        47
#            1       0.96      0.97      0.96        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Average Accuracy Score:
#
# 0.9531597332486503
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using K-Nearest Neighbors-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.035) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.035) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.961 (+/-0.043) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.961 (+/-0.043) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.957 (+/-0.058) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.957 (+/-0.058) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.029) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.029) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.968 (+/-0.017) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.968 (+/-0.017) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.963 (+/-0.026) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.963 (+/-0.026) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.031) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.969 (+/-0.029) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.964 (+/-0.057) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.967 (+/-0.045) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.959 (+/-0.028) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.964 (+/-0.035) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.035) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.035) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.961 (+/-0.043) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.961 (+/-0.043) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.957 (+/-0.058) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.957 (+/-0.058) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.029) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.029) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.968 (+/-0.017) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.968 (+/-0.017) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.963 (+/-0.026) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.963 (+/-0.026) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.031) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.969 (+/-0.029) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.964 (+/-0.057) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.967 (+/-0.045) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.959 (+/-0.028) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.964 (+/-0.035) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.035) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.035) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.961 (+/-0.043) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.961 (+/-0.043) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.957 (+/-0.058) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.957 (+/-0.058) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.029) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.971 (+/-0.029) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.968 (+/-0.017) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.968 (+/-0.017) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.963 (+/-0.026) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.963 (+/-0.026) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.971 (+/-0.031) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.969 (+/-0.029) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.964 (+/-0.057) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.967 (+/-0.045) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.959 (+/-0.028) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.964 (+/-0.035) for {'algorithm': 'brute', 'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        47
#            1       0.96      0.97      0.96        67
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Average Accuracy Score:
#
# 0.9562020460358056
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
#
# Grid scores on development set:
#
# 0.963 (+/-0.036) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.963 (+/-0.036) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.953 (+/-0.046) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.953 (+/-0.046) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.953 (+/-0.060) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.953 (+/-0.060) for {'algorithm': 'ball_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.963 (+/-0.042) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.963 (+/-0.042) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.961 (+/-0.028) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.961 (+/-0.028) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.956 (+/-0.034) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.956 (+/-0.034) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.958 (+/-0.055) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.955 (+/-0.048) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.951 (+/-0.060) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.952 (+/-0.054) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.950 (+/-0.043) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.951 (+/-0.038) for {'algorithm': 'ball_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.963 (+/-0.036) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.963 (+/-0.036) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.953 (+/-0.046) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.953 (+/-0.046) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.953 (+/-0.060) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.953 (+/-0.060) for {'algorithm': 'kd_tree', 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.963 (+/-0.042) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.963 (+/-0.042) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.961 (+/-0.028) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.961 (+/-0.028) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.956 (+/-0.034) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.956 (+/-0.034) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.958 (+/-0.055) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.955 (+/-0.048) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.951 (+/-0.060) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.952 (+/-0.054) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.950 (+/-0.043) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.951 (+/-0.038) for {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.963 (+/-0.036) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.963 (+/-0.036) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.953 (+/-0.046) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.953 (+/-0.046) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.953 (+/-0.060) for {'algorithm': 'brute', 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# ...
# 0.942 (+/-0.023) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 100}
# 0.946 (+/-0.051) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 250}
# 0.942 (+/-0.044) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 400}
# 0.941 (+/-0.037) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 500}
# 0.939 (+/-0.046) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.950 (+/-0.046) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.947 (+/-0.056) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.949 (+/-0.051) for {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 500}
# 0.959 (+/-0.056) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 100}
# 0.958 (+/-0.053) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 250}
# 0.954 (+/-0.064) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 400}
# 0.958 (+/-0.050) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 500}
# 0.958 (+/-0.060) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.955 (+/-0.053) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.961 (+/-0.048) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.958 (+/-0.056) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 500}
# 0.937 (+/-0.043) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# 0.940 (+/-0.051) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 250}
# 0.953 (+/-0.044) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 400}
# 0.934 (+/-0.059) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# 0.938 (+/-0.052) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.939 (+/-0.065) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.946 (+/-0.049) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.958 (+/-0.028) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# 0.947 (+/-0.054) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 100}
# 0.941 (+/-0.046) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 250}
# 0.940 (+/-0.035) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 400}
# 0.936 (+/-0.031) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'log2', 'n_estimators': 500}
# 0.937 (+/-0.062) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.952 (+/-0.058) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 250}
# 0.944 (+/-0.046) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 400}
# 0.947 (+/-0.069) for {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 50, 'max_features': 'sqrt', 'n_estimators': 500}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        47
#            1       0.98      0.97      0.98        67
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Average Accuracy Score:
#
# 0.9744363289933312
#
# #############################################################################################################################
#
# -------------Showing below the results obtained using XGB Model-----------------
#
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
#
# Grid scores on development set:
#
# 0.959 (+/-0.030) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.959 (+/-0.030) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.959 (+/-0.030) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.959 (+/-0.030) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.951 (+/-0.021) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.958 (+/-0.039) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.959 (+/-0.043) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.956 (+/-0.035) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.957 (+/-0.027) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.961 (+/-0.029) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.961 (+/-0.029) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.961 (+/-0.029) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.949 (+/-0.014) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.959 (+/-0.030) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.959 (+/-0.030) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.959 (+/-0.030) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.959 (+/-0.030) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.951 (+/-0.021) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.958 (+/-0.039) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.959 (+/-0.043) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.956 (+/-0.035) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.957 (+/-0.027) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.961 (+/-0.029) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.961 (+/-0.029) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.961 (+/-0.029) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        47
#            1       0.99      0.99      0.99        67
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Average Accuracy Score:
#
# 0.9818990155604954
#
# #############################################################################################################################
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
#
# Grid scores on development set:
#
# 0.956 (+/-0.036) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.956 (+/-0.036) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.956 (+/-0.036) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.956 (+/-0.036) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.945 (+/-0.031) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.953 (+/-0.033) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.956 (+/-0.041) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.954 (+/-0.036) for {'booster': 'gbtree', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.953 (+/-0.031) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.958 (+/-0.037) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.958 (+/-0.037) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.958 (+/-0.037) for {'booster': 'gbtree', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.900 (+/-0.031) for {'booster': 'gblinear', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.956 (+/-0.036) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.956 (+/-0.036) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.956 (+/-0.036) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.956 (+/-0.036) for {'booster': 'dart', 'learning_rate': 0.1, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.945 (+/-0.031) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.953 (+/-0.033) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.956 (+/-0.041) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.954 (+/-0.036) for {'booster': 'dart', 'learning_rate': 0.05, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# 0.953 (+/-0.031) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 100}
# 0.958 (+/-0.037) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 250}
# 0.958 (+/-0.037) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 400}
# 0.958 (+/-0.037) for {'booster': 'dart', 'learning_rate': 0.2, 'max_delta_step': 0, 'min_child_weight': 1, 'n_estimators': 500}
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        47
#            1       0.99      0.99      0.99        67
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Average Accuracy Score:
#
# 0.9818990155604954
#
# #############################################################################################################################
